# %%
import cv2

# Initialize the camera (0 for the default camera)
cap = cv2.VideoCapture(0)

# Check if the camera is opened successfully
if not cap.isOpened():
    print("Error: Could not open the camera.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Failed to capture image.")
        break
    
    # Display the resulting frame
    cv2.imshow("Camera Feed", frame)
    
    # Wait for the 'q' key to be pressed, and break the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture object and close any OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
#       9     exit()
#      11 while True:
#      12     # Capture frame-by-frame
# ---> 13     ret, frame = cap.read()
#      15     if not ret:
#      16         print("Error: Failed to capture image.")
#
# KeyboardInterrupt:

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLO model (YOLOv5 or YOLOv8)
model = YOLO(r"C:\Users\alie0\Downloads\train9\train9\weights\best.pt")  # You can use different model sizes like yolov8s.pt, yolov8m.pt, etc.

# Initialize the camera (0 for the default camera)
cap = cv2.VideoCapture(0)

# Check if the camera is opened successfully
if not cap.isOpened():
    print("Error: Could not open the camera.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Failed to capture image.")
        break

    # Perform YOLO inference on the captured frame
    results = model(frame)  # This applies the YOLO model to the frame

    # Annotate the frame with the results
    annotated_frame = results[0].plot()  # This adds bounding boxes, labels, etc.

    # Display the resulting frame with YOLO predictions
    cv2.imshow("YOLO Object Detection", annotated_frame)
    
    # Wait for the 'q' key to be pressed, and break the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture object and close any OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x416 (no detections), 197.6ms
# Speed: 4.7ms preprocess, 197.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 476.8ms
# Speed: 127.9ms preprocess, 476.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 558.2ms
# Speed: 10.9ms preprocess, 558.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 1286.5ms
# Speed: 12.4ms preprocess, 1286.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 124.7ms
# Speed: 6.4ms preprocess, 124.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 116.8ms
# Speed: 2.0ms preprocess, 116.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 111.9ms
# Speed: 3.0ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLO model (YOLOv5 or YOLOv8)
model = YOLO(r"C:\Users\alie0\Downloads\train9\train9\weights\best.pt")  # Use raw string to avoid escape sequence issues

# Initialize the camera (0 for the default camera)
cap = cv2.VideoCapture(0)

# Check if the camera is opened successfully
if not cap.isOpened():
    print("Error: Could not open the camera.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture image.")
        break

    # Perform YOLO inference on the captured frame
    results = model(frame)  # This applies the YOLO model to the frame

    # Extract the class names from the model
    class_names = results.names

    # Annotate the frame with the results (bounding boxes, class labels, etc.)
    annotated_frame = results[0].plot()  # This adds bounding boxes, labels, etc.

    # Loop through the results and print the class names
    for r in results:
        for c in r.boxes.cls:  # r.boxes.cls contains the class indices for detected objects
            print(class_names[int(c)])  # Convert the class index to the class name

    # Display the resulting frame with YOLO predictions
    cv2.imshow("YOLO Object Detection", annotated_frame)

    # Wait for the 'q' key to be pressed, and break the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture object and close any OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x416 1 babypowder, 154.1ms
# Speed: 6.0ms preprocess, 154.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 416)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 27
#      24 results = model(frame)  # This applies the YOLO model to the frame
#      26 # Extract the class names from the model
# ---> 27 class_names = results.names
#      29 # Annotate the frame with the results (bounding boxes, class labels, etc.)
#      30 annotated_frame = results[0].plot()  # This adds bounding boxes, labels, etc.
#
# AttributeError: 'list' object has no attribute 'names'

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLO model (YOLOv5 or YOLOv8)
model = YOLO(r"C:\Users\alie0\Downloads\best (2).pt")  # Use raw string to avoid escape sequence issues

# Initialize the camera (0 for the default camera)
cap = cv2.VideoCapture(0)

# Check if the camera is opened successfully
if not cap.isOpened():
    print("Error: Could not open the camera.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture image.")
        break

    # Perform YOLO inference on the captured frame
    results = model(frame)  # This applies the YOLO model to the frame

    # Access the first result (in case of batch inference)
    result = results[0]

    # Extract the class names from the model
    class_names = result.names

    # Annotate the frame with the results (bounding boxes, class labels, etc.)
    annotated_frame = result.plot()  # This adds bounding boxes, labels, etc.

    # Loop through the detected boxes and print the class names
    for cls in result.boxes.cls:  # result.boxes.cls contains the class indices for detected objects
        class_name = class_names[int(cls)]  # Convert the class index to the class name
        print(class_name)

    # Display the resulting frame with YOLO predictions
    cv2.imshow("YOLO Object Detection", annotated_frame)

    # Wait for the 'q' key to be pressed, and break the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture object and close any OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x416 (no detections), 173.9ms
# Speed: 26.7ms preprocess, 173.9ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 183.4ms
# Speed: 76.7ms preprocess, 183.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 62.6ms
# Speed: 2.3ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 73.6ms
# Speed: 2.5ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 60.1ms
# Speed: 4.4ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLO model (YOLOv5 or YOLOv8)
model = YOLO(r"C:\Users\alie0\Downloads\train9\train9\weights\best.pt")  # Use raw string to avoid escape sequence issues

# Initialize the camera (0 for the default camera)
cap = cv2.VideoCapture(0)

# Check if the camera is opened successfully
if not cap.isOpened():
    print("Error: Could not open the camera.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture image.")
        break

    # Resize the frame to the expected input size for YOLO
    frame_resized = cv2.resize(frame, (640, 640))  # or (416, 416)

    # Convert from BGR to RGB (YOLO models expect RGB input)
    frame_rgb = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2RGB)

    # Perform YOLO inference on the captured frame
    results = model(frame_rgb)  # This applies the YOLO model to the frame

    # Access the first result (in case of batch inference)
    result = results[0]

    # Extract the class names from the model
    class_names = result.names

    # Annotate the frame with the results (bounding boxes, class labels, etc.)
    annotated_frame = result.plot()  # This adds bounding boxes, labels, etc.

    # Loop through the detected boxes and print the class names
    for cls in result.boxes.cls:  # result.boxes.cls contains the class indices for detected objects
        class_name = class_names[int(cls)]  # Convert the class index to the class name
        print(class_name)

    # Display the resulting frame with YOLO predictions
    cv2.imshow("YOLO Object Detection", annotated_frame)

    # Wait for the 'q' key to be pressed, and break the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture object and close any OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 416x416 (no detections), 210.0ms
# Speed: 9.3ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 (no detections), 100.4ms
# Speed: 3.3ms preprocess, 100.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 (no detections), 121.3ms
# Speed: 4.0ms preprocess, 121.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 (no detections), 119.2ms
# Speed: 2.0ms preprocess, 119.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 (no detections), 111.7ms
# Speed: 4.5ms preprocess, 111.7ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 (no detections), 72.9ms
# Speed: 3.2ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 (no detections), 72.8ms
# Speed: 3.0ms preprocess, 72.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 416)
#
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLO model (YOLOv5 or YOLOv8)
model = YOLO(r"C:\Users\alie0\Downloads\best.pt")  # Use raw string to avoid escape sequence issues

# Initialize the camera (0 for the default camera)
cap = cv2.VideoCapture(0)

# Check if the camera is opened successfully
if not cap.isOpened():
    print("Error: Could not open the camera.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture image.")
        break

    # Resize the frame to the expected input size for YOLO
    frame_resized = cv2.resize(frame, (640, 640))  # or (416, 416)

    # Convert from BGR to RGB (YOLO models expect RGB input)
    frame_rgb = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2RGB)

    # Perform YOLO inference on the captured frame
    results = model(frame_rgb)  # This applies the YOLO model to the frame

    # Access the first result (in case of batch inference)
    result = results[0]

    # Extract the class names from the model
    class_names = result.names

    # Annotate the frame with the results (bounding boxes, class labels, etc.)
    annotated_frame = result.plot()  # This adds bounding boxes, labels, etc.

    # Loop through the detected boxes and print the class names
    for cls in result.boxes.cls:  # result.boxes.cls contains the class indices for detected objects
        class_name = class_names[int(cls)]  # Convert the class index to the class name
        print(class_name)

    # Display the resulting frame with YOLO predictions
    cv2.imshow("YOLO Object Detection", annotated_frame)

    # Wait for the 'q' key to be pressed, and break the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture object and close any OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\alie0\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\cuda\__init__.py:129: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11060). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\c10\cuda\CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# 0: 640x640 1 soap, 422.0ms
# Speed: 34.4ms preprocess, 422.0ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 640)
# soap
#
# 0: 640x640 2 soaps, 1103.0ms
# Speed: 303.5ms preprocess, 1103.0ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
# soap
# soap
#
# 0: 640x640 1 soap, 689.9ms
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLO model (YOLOv5 or YOLOv8)
model = YOLO(r"C:\Users\alie0\Downloads\train9\train9\weights\best.pt")
from PIL import Image
image_path = r"C:\Users\alie0\Downloads\Cotton-Wool-Pads-80.webp"


results = model.predict(source=image_path, imgsz=512)  # source=path to the image

# Get the class names (model.names will have the class labels)
names = model.names

# Process the results (bounding boxes, class predictions)
for r in results:
    for c in r.boxes.cls:  # r.boxes.cls contains the predicted class indices
        print(names[int(c)])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cv2
# ----> 2 from ultralytics import YOLO
#       4 # Load the pre-trained YOLO model (YOLOv5 or YOLOv8)
#       5 model = YOLO(r"C:\Users\alie0\Downloads\train9\train9\weights\best.pt")
#
# ModuleNotFoundError: No module named 'ultralytics'
